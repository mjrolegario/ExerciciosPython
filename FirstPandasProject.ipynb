# %%
#importando o pandas
import pandas as pd 
#lendo o arquivo
tabela_work = pd.read_csv("Salarios.csv")
#mostrando a tabela de dados
display(tabela_work)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#total de colunas e linhas da tabela 

linhas = tabela_work.shape[0]
colunas = tabela_work.shape[1]

print("A tabela tem o total de " + str(colunas) + " colunas e " + str(linhas) + " linhas.")
# Out:
# A tebale tem o total de 13 colunas e 148654 linhas.

# %%
#Qual é o salário médio?

coluna_salario = tabela_work[["TotalPay"]].mean()
display(coluna_salario)
# Out:
# TotalPay    74768.321972
# dtype: float64

# %%
#Qual é o salário máximo?

maior_salario = tabela_work["TotalPay"].max()

print(maior_salario)
# Out:
# 567595.43

# %%
#Qual é o emprego do JOSEPH DRISCOLL?

emprego_joseph = tabela_work.loc[tabela_work["EmployeeName"]=="JOSEPH DRISCOLL","JobTitle"]
display("O emprego de Joseph Driscoll é " + emprego_joseph)
# Out:
# 24    O emprego de Joseph Driscoll é CAPTAIN, FIRE S...
# Name: JobTitle, dtype: object

# %%
#Qual o nome da pessoa que tem o maior salário de todos?

maior_salario = tabela_work["TotalPay"].max()
empregado_maiorSalario = tabela_work.loc[tabela_work["TotalPay"]==maior_salario,"EmployeeName"]

print(empregado_maiorSalario)
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
#Qual é o salário médio por ano?

media_salarios = tabela_work[["Year", "TotalPay"]].groupby("Year").mean()

display(media_salarios)
# Out:
#           TotalPay
# Year
# 2011  71744.103871
# 2012  74113.262265
# 2013  77611.443142
# 2014  75463.918140
